# %%
from keras import models, layers
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# %%
# load the data and devided into 2 sets call train and test data sets 
# training set consists of 60,000 28x28 pixel images, and the test set 10,000.
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape, test_images.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
# initializing the sequential model
model = models.Sequential()
# input layer
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
# hidden layers 
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
# output layer contains 10 neurons for each 0 - 9 digits 
model.add(layers.Dense(10, activation='softmax'))

# compiling the model 
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# view model summary which we have created 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
# reshaping the train images 
train_images = train_images.reshape((60000, 28, 28, 1))
train_images= train_images.astype('float32') / 255 # rescale pixel values from range [0, 255] to [0, 1]

# reshaping the test images  
test_images = test_images.reshape((10000, 28, 28, 1))
test_images= test_images.astype('float32') / 255

# label encoding 
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# data partition for model validation
validation_images = train_images[50000:]
validation_labels = train_labels[50000:]

# data partition for model training 
train_images = train_images[:50000]
train_labels = train_labels[:50000]

# train the model
history = model.fit(train_images, train_labels, epochs=20, batch_size=64, validation_data=(validation_images, validation_labels))
# Out:
# Epoch 1/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.1945 - accuracy: 0.9394 - val_loss: 0.0584 - val_accuracy: 0.9831
# Epoch 2/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0530 - accuracy: 0.9831 - val_loss: 0.0369 - val_accuracy: 0.9900
# Epoch 3/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0355 - accuracy: 0.9892 - val_loss: 0.0397 - val_accuracy: 0.9889
# Epoch 4/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0266 - accuracy: 0.9915 - val_loss: 0.0383 - val_accuracy: 0.9900
# Epoch 5/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0213 - accuracy: 0.9934 - val_loss: 0.0496 - val_accuracy: 0.9875
# Epoch 6/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0170 - accuracy: 0.9947 - val_loss: 0.0374 - val_accuracy: 0.9893
# Epoch 7/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0142 - accuracy: 0.9956 - val_loss: 0.0371 - val_accuracy: 0.9913
# Epoch 8/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.0409 - val_accuracy: 0.9914
# Epoch 9/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.0669 - val_accuracy: 0.9869
# Epoch 10/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0515 - val_accuracy: 0.9903
# Epoch 11/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0665 - val_accuracy: 0.9887
# Epoch 12/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0553 - val_accuracy: 0.9912
# Epoch 13/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0673 - val_accuracy: 0.9904
# Epoch 14/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.1035 - val_accuracy: 0.9880
# Epoch 15/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0634 - val_accuracy: 0.9907
# Epoch 16/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0799 - val_accuracy: 0.9895
# Epoch 17/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0735 - val_accuracy: 0.9907
# Epoch 18/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.0662 - val_accuracy: 0.9919
# Epoch 19/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0729 - val_accuracy: 0.9918
# Epoch 20/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0745 - val_accuracy: 0.9928

# %%
# validating the model
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Accuracy:', test_acc)
print('Loss: ', test_loss)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0624 - accuracy: 0.9916
# Accuracy: 0.991599977016449
# Loss:  0.06243409961462021
